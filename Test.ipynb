# %%
# Python modules
import json
import csv

# Add-on modules
import tensorflow as tf

# %% [markdown]
# Testing out json methods and exploring the json files

# %%
with open('Train/train.json', mode='r', encoding='utf-8') as f:
    train=json.load(f)

# %%
with open('Validation/val_open.json', mode='r', encoding='utf-8') as f:
    val=json.load(f)

# %%
train
# Out:
# {'info': None,
#  'lincenses': None,
#  'images': [{'file_name': 'images_withoutrect/11003.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11003},
#   {'file_name': 'images_withoutrect/11004.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11004},
#   {'file_name': 'images_withoutrect/11005.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11005},
#   {'file_name': 'images_withoutrect/11006.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11006},
#   {'file_name': 'images_withoutrect/11007.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11007},
#   {'file_name': 'images_withoutrect/11008.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11008},
#   {'file_name': 'images_withoutrect/11010.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11010},
#   {'file_name': 'images_withoutrect/11011.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 11011},
# ...

# %%
val
# Out:
# {'info': None,
#  'lincenses': None,
#  'images': [{'file_name': 'images_withoutrect/73dfda677df7.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': '73dfda677df7'},
#   {'file_name': 'images_withoutrect/a44d8a314235.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 'a44d8a314235'},
#   {'file_name': 'images_withoutrect/132540e06a7f.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': '132540e06a7f'},
#   {'file_name': 'images_withoutrect/92985df16b8c.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': '92985df16b8c'},
#   {'file_name': 'images_withoutrect/b677bcb53c0d.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 'b677bcb53c0d'},
#   {'file_name': 'images_withoutrect/4b7f69aaf35f.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': '4b7f69aaf35f'},
#   {'file_name': 'images_withoutrect/c162cd332299.png',
#    'height': 1080,
#    'width': 1920,
#    'image_id': 'c162cd332299'},
# ...

# %%
print(train['images'][0])
# Out:
# {'file_name': 'images_withoutrect/11003.png', 'height': 1080, 'width': 1920, 'image_id': 11003}

# %%
print(train['annotations'][0])
# Out:
# {'area': 81909.20209190401, 'iscrowd': 0, 'image_id': 11003, 'bbox': [636.08832, 305.77176, 298.5888, 274.32108000000005], 'category_id': 2}

# %%
print(train['categories'][0])
# Out:
# {'id': 1, 'name': '瓜子壳'}

# %%
print(val['images'][0])
# Out:
# {'file_name': 'images_withoutrect/73dfda677df7.png', 'height': 1080, 'width': 1920, 'image_id': '73dfda677df7'}

# %%
print(val['categories'][0])
# Out:
# {'id': 1, 'name': '瓜子壳'}

# %% [markdown]
# Testing out csv methods

# %%
headers=['file_name', 'image_id', 'category_id', 'category_name']

with open('Train/train.csv', mode='w', newline='') as f:
    f_csv=csv.writer(f,headers)
    f_csv.writerow(headers)
    for i in range(80000):
        f_csv.writerow([
            train['images'][i]['file_name'],
            train['images'][i]['image_id'],
            train['annotations'][i]['category_id'],
            train['categories'][train['annotations'][i]['category_id']-1]['name']
        ])

# %% [markdown]
# Testing out tensorflow with GPU

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17394632520869364592, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 6574135706
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12068222371800711800
#  physical_device_desc: "device: 0, name: GeForce RTX 2080 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5"]
